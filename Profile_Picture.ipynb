# %%
import CrystalGraphs
import numpy as np
t = np.linspace(0, 2*np.pi, 1000)
CrystalGraphs.ax.grid(False)
CrystalGraphs.size = .1
CrystalGraphs.fcc(20, [0,0,0,'white'], [.25,.25,.25,'cyan'], draw_path=False)
CrystalGraphs.ax.view_init(elev=35, azim=45)
CrystalGraphs.ax.set_axis_off()
CrystalGraphs.set_axes_equal(CrystalGraphs.ax)
CrystalGraphs.ax.lines = []
CrystalGraphs.plt.show()
# CrystalGraphs.plt.savefig('diamond_profile_picture_black.png', transparent=False)
